# %%
# 1 Import the necessary libraries.

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 2 Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df

customer_df = pd.read_csv('files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
# 3 First look at its main features (head, shape, info). NOTE The target column is total_claim_amount
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   Total Claim Amount  Vehicle Class Vehicle Size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
customer_df.shape
# Out:
# (9134, 24)

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
#  12  Monthly Premium Auto           9134 non-null   int64
#  13  Months Since Last Claim        9134 non-null   int64
#  14  Months Since Policy Inception  9134 non-null   int64
#  15  Number of Open Complaints      9134 non-null   int64
#  16  Number of Policies             9134 non-null   int64
#  17  Policy Type                    9134 non-null   object
#  18  Policy                         9134 non-null   object
#  19  Renew Offer Type               9134 non-null   object
#  20  Sales Channel                  9134 non-null   object
#  21  Total Claim Amount             9134 non-null   float64
#  22  Vehicle Class                  9134 non-null   object
#  23  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB

# %%
# 4 Rename the columns so they follow the PE8 (snake case) (lower_case_with_underscores)
customer_df.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
def snake_case(x):
    x = x.replace(' ', '_').lower()
    print(x)
    return x
    
snake_case('Customer Lifetime Value')

customer_df.columns = customer_df.columns.map(snake_case)
# Out:
# customer_lifetime_value
# customer
# state
# customer_lifetime_value
# response
# coverage
# education
# effective_to_date
# employmentstatus
# gender
# income
# location_code
# marital_status
# monthly_premium_auto
# months_since_last_claim
# months_since_policy_inception
# number_of_open_complaints
# number_of_policies
# policy_type
# policy
# renew_offer_type
# sales_channel
# total_claim_amount
# vehicle_class
# vehicle_size

# %%
customer_df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   total_claim_amount  vehicle_class vehicle_size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
# 5 Change effective to date column to datetime format.
def convert_into_date(x):
    return pd.to_datetime(x, format='%m/%d/%y')

customer_df['effective_to_date'] = customer_df['effective_to_date'].map(convert_into_date)

# %%
customer_df['effective_to_date']
customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# 0     Bachelor        2011-02-24         Employed      F   56274  ...
# 1     Bachelor        2011-01-31       Unemployed      F       0  ...
# 2     Bachelor        2011-02-19         Employed      F   48767  ...
# 3     Bachelor        2011-01-20       Unemployed      M       0  ...
# 4     Bachelor        2011-02-03         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor        2011-02-10         Employed      M   71941  ...
# 9130   College        2011-02-12         Employed      F   21604  ...
# 9131  Bachelor        2011-02-06       Unemployed      M       0  ...
# 9132   College        2011-02-03         Employed      M   21941  ...
# 9133   College        2011-02-14       Unemployed      M       0  ...
#
#      months_since_policy_inception number_of_open_complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       number_of_policies     policy_type        policy  renew_offer_type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       sales_channel total_claim_amount  vehicle_class vehicle_size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
# 6 Create a NEW dataframe using only the numerical data called numerical_df. Use this for the following questions.

numerical_df = customer_df.select_dtypes(include='number')

# %%
numerical_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1          384.811147
# 1                             0                   8         1131.464935
# 2                             0                   2          566.472247
# 3                             0                   7          529.881344
# 4                             0                   1          138.130879
# ...                         ...                 ...                 ...
# 9129                          0                   2          198.234764
# 9130                          0                   1          379.200000
# 9131                          3                   2          790.784983
# 9132                          0                   3          691.200000
# 9133                          0                   1          369.600000
#
# [9134 rows x 8 columns]

# %%
# 7 Define a function that differentiates between continuous and discrete variables. Hint: The number of unique values might be useful. 
# Store continuous data into a continuous_df variable and do the same for discrete_df

for column in numerical_df.columns:
    print(column, numerical_df[column].nunique())
# Out:
# customer_lifetime_value 8041
# income 5694
# monthly_premium_auto 202
# months_since_last_claim 36
# months_since_policy_inception 100
# number_of_open_complaints 6
# number_of_policies 9
# total_claim_amount 5106

# %%
def cat_cont_discrete(x):
    continuous_df_col = []
    discrete_df_col = []

    for column in numerical_df.columns:
        if numerical_df[column].nunique() > 20:
            continuous_df_col.append(column)
        else:
            discrete_df_col.append(column)
    
    cont = numerical_df[continuous_df_col]
    discrete = numerical_df[discrete_df_col]
    
    return cont, discrete


continuous_df, discrete_df = cat_cont_discrete(numerical_df)

# %%
continuous_df.head()
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  total_claim_amount
# 0                       32                              5          384.811147
# 1                       13                             42         1131.464935
# 2                       18                             38          566.472247
# 3                       18                             65          529.881344
# 4                       12                             44          138.130879

# %%
discrete_df.head()
# Out:
#    number_of_open_complaints  number_of_policies
# 0                          0                   1
# 1                          0                   8
# 2                          0                   2
# 3                          0                   7
# 4                          0                   1

# %%
# 8 Plot a correlation matrix, comment what you see.
correlations_matrix = continuous_df.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# I do not see any too high correlation among features, I do not think I should drop something

# %%
# 9 Create a function to plot every discrete variable. Do the same with the continuous variables 
# (Be Careful, you may need to change the plot type to one better suited for continuous data!)

plt.figure(figsize=(10, 6))
sns.barplot(data=discrete_df, x='number_of_open_complaints', y='number_of_policies')

plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
sns.barplot(data=discrete_df, x='number_of_open_complaints', y='number_of_policies')

plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# 10 Comment what you can see in the plots.
# They do not seem to be correlated either among features neither with the target

# %%
# 11 Look for outliers in the continuous variables. (HINT: There’s a good plot to do that!)

for col in continuous_df.columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=continuous_df[col])
    plt.title(col)
    plt.show()

# %%
customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# 0     Bachelor        2011-02-24         Employed      F   56274  ...
# 1     Bachelor        2011-01-31       Unemployed      F       0  ...
# 2     Bachelor        2011-02-19         Employed      F   48767  ...
# 3     Bachelor        2011-01-20       Unemployed      M       0  ...
# 4     Bachelor        2011-02-03         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor        2011-02-10         Employed      M   71941  ...
# 9130   College        2011-02-12         Employed      F   21604  ...
# 9131  Bachelor        2011-02-06       Unemployed      M       0  ...
# 9132   College        2011-02-03         Employed      M   21941  ...
# 9133   College        2011-02-14       Unemployed      M       0  ...
#
#      months_since_policy_inception number_of_open_complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       number_of_policies     policy_type        policy  renew_offer_type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       sales_channel total_claim_amount  vehicle_class vehicle_size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
for col in discrete_df.columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=discrete_df[col])
    plt.title(col)
    plt.show()

# %%
# 11 Look for outliers in the continuous variables. (HINT: There’s a good plot to do that!)
# 12 Did you find outliers? Comment what you will do with them. If you decide to remove them, do that now. Also, remove them from your main dataframe.

# I can see outliers for both customer_life_time_value and total_claim_amount.
# I will not delete any outlier for the target, going to delete them for the feature customer_life_time_value
# because I am assuming they are not representative of the model

customer_df['customer_lifetime_value']

top_limit = customer_df['customer_lifetime_value'].quantile(0.95)
customer_df = customer_df[customer_df['customer_lifetime_value'] <= top_limit]
continuous_df = continuous_df[continuous_df['customer_lifetime_value'] <= top_limit]

# %%
customer_df
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9128  YM19146  California              4100.398533       No   Premium
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective_to_date employmentstatus gender  income  ...  \
# 0     Bachelor        2011-02-24         Employed      F   56274  ...
# 1     Bachelor        2011-01-31       Unemployed      F       0  ...
# 2     Bachelor        2011-02-19         Employed      F   48767  ...
# 3     Bachelor        2011-01-20       Unemployed      M       0  ...
# 4     Bachelor        2011-02-03         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9128   College        2011-01-06         Employed      F   47761  ...
# 9130   College        2011-02-12         Employed      F   21604  ...
# 9131  Bachelor        2011-02-06       Unemployed      M       0  ...
# 9132   College        2011-02-03         Employed      M   21941  ...
# 9133   College        2011-02-14       Unemployed      M       0  ...
#
#      months_since_policy_inception number_of_open_complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9128                            58                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       number_of_policies     policy_type        policy  renew_offer_type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9128                   1   Personal Auto   Personal L2            Offer1
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       sales_channel total_claim_amount  vehicle_class vehicle_size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9128         Branch         541.282007  Four-Door Car        Large
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [8677 rows x 24 columns]

# %%
# 13 Check all columns for NaN values. Decide what (if anything) you will need to do with them, do that now.

customer_df.isna().value_counts().T
# Out:
# customer  state  customer_lifetime_value  response  coverage  education  effective_to_date  employmentstatus  gender  income  location_code  marital_status  monthly_premium_auto  months_since_last_claim  months_since_policy_inception  number_of_open_complaints  number_of_policies  policy_type  policy  renew_offer_type  sales_channel  total_claim_amount  vehicle_class  vehicle_size
# False     False  False                    False     False     False      False              False             False   False   False          False           False                 False                    False                          False                      False               False        False   False             False          False               False          False           8677
# dtype: int64

# %%
# I do not find any nan

numerical_df.isna().sum()
# Out:
# customer_lifetime_value          0
# income                           0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# total_claim_amount               0
# dtype: int64

# %%
# 14 Save the numerical_df to csv as numerical.csv You will use this file again this week.
numerical_df.to_csv('numerical_data.csv', index=False)

# %% [markdown]
# PART 2 -- CATEGORICALS

# %%
# 1 Open the notebook created for Lab-cleaning-numerical-data.
# 2 Find all of the categorical data. Save it in a categorical_df =  variable.

categorical_df = customer_df.select_dtypes(include='object')

# %%
# 3 Check for NaN values and decide what to do with them, do it now.

categorical_df.isna().sum()

# I do not see any NaN values
# Out:
# customer            0
# state               0
# response            0
# coverage            0
# education           0
# employmentstatus    0
# gender              0
# location_code       0
# marital_status      0
# policy_type         0
# policy              0
# renew_offer_type    0
# sales_channel       0
# vehicle_class       0
# vehicle_size        0
# dtype: int64

# %%
# 4 Check all unique values of columns.

for col in categorical_df.columns:
   print(categorical_df[col].value_counts(dropna=False))
# Out:
# BU79786    1
# RN86953    1
# DB50188    1
# XO38850    1
# WW52683    1
#           ..
# GT66241    1
# KO95143    1
# CN13435    1
# DW14769    1
# Y167826    1
# Name: customer, Length: 8677, dtype: int64
# California    3009
# Oregon        2464
# Arizona       1618
# Nevada         830
# Washington     756
# Name: state, dtype: int64
# No     7441
# Yes    1236
# Name: response, dtype: int64
# Basic       5341
# Extended    2577
# Premium      759
# Name: coverage, dtype: int64
# Bachelor                2609
# College                 2559
# High School or Below    2480
# Master                   703
# Doctor                   326
# Name: education, dtype: int64
# Employed         5391
# Unemployed       2230
# Medical Leave     409
# Disabled          382
# Retired           265
# Name: employmentstatus, dtype: int64
# F    4410
# M    4267
# Name: gender, dtype: int64
# Suburban    5500
# Rural       1684
# Urban       1493
# Name: location_code, dtype: int64
# Married     5034
# Single      2353
# Divorced    1290
# Name: marital_status, dtype: int64
# Personal Auto     6447
# Corporate Auto    1876
# Special Auto       354
# Name: policy_type, dtype: int64
# Personal L3     3250
# Personal L2     2013
# Personal L1     1184
# Corporate L3     965
# Corporate L2     573
# Corporate L1     338
# Special L2       154
# Special L3       138
# Special L1        62
# Name: policy, dtype: int64
# Offer1    3536
# Offer2    2803
# Offer3    1360
# Offer4     978
# Name: renew_offer_type, dtype: int64
# Agent          3323
# Branch         2416
# Call Center    1674
# Web            1264
# Name: sales_channel, dtype: int64
# Four-Door Car    4473
# Two-Door Car     1838
# SUV              1650
# Sports Car        434
# Luxury SUV        151
# Luxury Car        131
# Name: vehicle_class, dtype: int64
# Medsize    6093
# Small      1673
# Large       911
# Name: vehicle_size, dtype: int64

# %%
# 5 Check dtypes. Do they all make sense as categorical data?

categorical_df.dtypes

# Yes, they are all objects (string)
# Out:
# customer            object
# state               object
# response            object
# coverage            object
# education           object
# employmentstatus    object
# gender              object
# location_code       object
# marital_status      object
# policy_type         object
# policy              object
# renew_offer_type    object
# sales_channel       object
# vehicle_class       object
# vehicle_size        object
# dtype: object

# %%
# 6 Does any column contain alpha and numeric data? Decide how to clean it and do it now.

categorical_df.head()
# Out:
#   customer       state response  coverage education employmentstatus gender  \
# 0  BU79786  Washington       No     Basic  Bachelor         Employed      F
# 1  QZ44356     Arizona       No  Extended  Bachelor       Unemployed      F
# 2  AI49188      Nevada       No   Premium  Bachelor         Employed      F
# 3  WW63253  California       No     Basic  Bachelor       Unemployed      M
# 4  HB64268  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
#   sales_channel  vehicle_class vehicle_size
# 0         Agent   Two-Door Car      Medsize
# 1         Agent  Four-Door Car      Medsize
# 2         Agent   Two-Door Car      Medsize
# 3   Call Center            SUV      Medsize
# 4         Agent  Four-Door Car      Medsize

# %%
# The columns that are alphanumerical are the following: customer, policy, renew_offer_type

categorical_df['renew_offer_type'].unique()
# Out:
# array(['Offer1', 'Offer3', 'Offer2', 'Offer4'], dtype=object)

# %%
# There is no use in treat customer the colum will be dropped, same for renew_offer_type because
# it will be anyone encoded. I will treat only policy becuase it has redundad info (in common with policy_type)

# %%
def get_number_at_the_end(x):
    return x[len(x) - 1]

categorical_df['policy'] = categorical_df['policy'].apply(get_number_at_the_end)

# %%
categorical_df
# Out:
#      customer       state response  coverage education employmentstatus  \
# 0     BU79786  Washington       No     Basic  Bachelor         Employed
# 1     QZ44356     Arizona       No  Extended  Bachelor       Unemployed
# 2     AI49188      Nevada       No   Premium  Bachelor         Employed
# 3     WW63253  California       No     Basic  Bachelor       Unemployed
# 4     HB64268  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9128  YM19146  California       No   Premium   College         Employed
# 9130  PK87824  California      Yes  Extended   College         Employed
# 9131  TD14365  California       No  Extended  Bachelor       Unemployed
# 9132  UP19263  California       No  Extended   College         Employed
# 9133  Y167826  California       No  Extended   College       Unemployed
#
#      gender location_code marital_status     policy_type policy  \
# 0         F      Suburban        Married  Corporate Auto      3
# 1         F      Suburban         Single   Personal Auto      3
# 2         F      Suburban        Married   Personal Auto      3
# 3         M      Suburban        Married  Corporate Auto      2
# 4         M         Rural         Single   Personal Auto      1
# ...     ...           ...            ...             ...    ...
# 9128      F      Suburban         Single   Personal Auto      2
# 9130      F      Suburban       Divorced  Corporate Auto      3
# 9131      M      Suburban         Single  Corporate Auto      2
# 9132      M      Suburban        Married   Personal Auto      2
# 9133      M      Suburban         Single  Corporate Auto      3
#
#      renew_offer_type sales_channel  vehicle_class vehicle_size
# 0              Offer1         Agent   Two-Door Car      Medsize
# 1              Offer3         Agent  Four-Door Car      Medsize
# 2              Offer1         Agent   Two-Door Car      Medsize
# 3              Offer1   Call Center            SUV      Medsize
# 4              Offer1         Agent  Four-Door Car      Medsize
# ...               ...           ...            ...          ...
# 9128           Offer1        Branch  Four-Door Car        Large
# 9130           Offer1        Branch  Four-Door Car      Medsize
# 9131           Offer1        Branch  Four-Door Car      Medsize
# 9132           Offer3        Branch  Four-Door Car        Large
# 9133           Offer4   Call Center   Two-Door Car      Medsize
#
# [8677 rows x 15 columns]

# %%
# 7 Would you choose to do anything else to clean or wrangle the categorical data? Comment your decisions and do it now.
# 8 Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?
# policy and policy_type provide the same information. I will drop policy type. I do not see any other obvious things to be cleaned

categorical_df.drop('policy_type', axis=1, inplace=True)

# %%
categorical_df['vehicle_size'].unique()
# Out:
# array(['Medsize', 'Small', 'Large'], dtype=object)

# %%
# 9 Check number of unique values in each column, can they be combined in any way to ease encoding? Comment your thoughts and make those changes.
for col in categorical_df.columns:
    display(categorical_df[col].value_counts())


# 10 Save the cleaned catagorical dataframe as categorical.csv You will use this file again this week.
# Out:
# 'customer'
# array(['BU79786', 'QZ44356', 'AI49188', ..., 'TD14365', 'UP19263',
#        'Y167826'], dtype=object)
# BU79786    1
# RN86953    1
# DB50188    1
# XO38850    1
# WW52683    1
#           ..
# GT66241    1
# KO95143    1
# CN13435    1
# DW14769    1
# Y167826    1
# Name: customer, Length: 8677, dtype: int64
# 'state'
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon'],
#       dtype=object)
# California    3009
# Oregon        2464
# Arizona       1618
# Nevada         830
# Washington     756
# Name: state, dtype: int64
# 'response'
# array(['No', 'Yes'], dtype=object)
# No     7441
# Yes    1236
# Name: response, dtype: int64
# 'coverage'
# array(['Basic', 'Extended', 'Premium'], dtype=object)
# Basic       5341
# Extended    2577
# Premium      759
# Name: coverage, dtype: int64
# 'education'
# array(['Bachelor', 'College', 'Master', 'High School or Below', 'Doctor'],
#       dtype=object)
# Bachelor                2609
# College                 2559
# High School or Below    2480
# Master                   703
# Doctor                   326
# Name: education, dtype: int64
# 'employmentstatus'
# array(['Employed', 'Unemployed', 'Medical Leave', 'Disabled', 'Retired'],
#       dtype=object)
# Employed         5391
# Unemployed       2230
# Medical Leave     409
# Disabled          382
# Retired           265
# Name: employmentstatus, dtype: int64
# 'gender'
# array(['F', 'M'], dtype=object)
# F    4410
# M    4267
# Name: gender, dtype: int64
# 'location_code'
# array(['Suburban', 'Rural', 'Urban'], dtype=object)
# Suburban    5500
# Rural       1684
# Urban       1493
# Name: location_code, dtype: int64
# 'marital_status'
# array(['Married', 'Single', 'Divorced'], dtype=object)
# Married     5034
# Single      2353
# Divorced    1290
# Name: marital_status, dtype: int64
# 'policy'
# array(['3', '2', '1'], dtype=object)
# 3    4353
# 2    2740
# 1    1584
# Name: policy, dtype: int64
# 'renew_offer_type'
# array(['Offer1', 'Offer3', 'Offer2', 'Offer4'], dtype=object)
# Offer1    3536
# Offer2    2803
# Offer3    1360
# Offer4     978
# Name: renew_offer_type, dtype: int64
# 'sales_channel'
# array(['Agent', 'Call Center', 'Web', 'Branch'], dtype=object)
# Agent          3323
# Branch         2416
# Call Center    1674
# Web            1264
# Name: sales_channel, dtype: int64
# 'vehicle_class'
# array(['Two-Door Car', 'Four-Door Car', 'SUV', 'Luxury SUV', 'Sports Car',
#        'Luxury Car'], dtype=object)
# Four-Door Car    4473
# Two-Door Car     1838
# SUV              1650
# Sports Car        434
# Luxury SUV        151
# Luxury Car        131
# Name: vehicle_class, dtype: int64
# 'vehicle_size'
# array(['Medsize', 'Small', 'Large'], dtype=object)
# Medsize    6093
# Small      1673
# Large       911
# Name: vehicle_size, dtype: int64

# %%
def group_high_edu(x):
    if x in ['Master', 'Doctor']:
        return 'Master or Above'
    else:
        return x

categorical_df['education'] = categorical_df['education'].apply(group_high_edu)

# %%
categorical_df.head(50)
# Out:
#    customer       state response  coverage             education  \
# 0   BU79786  Washington       No     Basic              Bachelor
# 1   QZ44356     Arizona       No  Extended              Bachelor
# 2   AI49188      Nevada       No   Premium              Bachelor
# 3   WW63253  California       No     Basic              Bachelor
# 4   HB64268  Washington       No     Basic              Bachelor
# 5   OC83172      Oregon      Yes     Basic              Bachelor
# 6   XZ87318      Oregon      Yes     Basic               College
# 7   CF85061     Arizona       No   Premium       at least Master
# 9   BQ94931      Oregon       No  Extended               College
# 10  SX51350  California       No     Basic               College
# 11  VQ65197  California       No     Basic               College
# 12  DP39365  California       No   Premium       at least Master
# 13  SJ95423     Arizona      Yes     Basic  High School or Below
# 14  IL66569  California       No     Basic               College
# 15  BW63560      Oregon       No     Basic              Bachelor
# 16  FV94802      Nevada       No     Basic  High School or Below
# 17  OE15005  California       No     Basic               College
# 18  WC83389      Oregon       No     Basic               College
# 19  FL50705  California       No   Premium  High School or Below
# 20  ZK25313      Oregon       No     Basic  High School or Below
# 21  SV62436  Washington       No  Extended              Bachelor
# 23  TZ98966      Nevada       No     Basic              Bachelor
# 24  HM55802  California       No     Basic              Bachelor
# 25  FS42516      Oregon       No     Basic               College
# 26  US89481  California       No   Premium              Bachelor
# 27  HO30839  Washington       No  Extended       at least Master
# 28  GE62437     Arizona       No   Premium               College
# 29  EJ77678      Oregon       No  Extended       at least Master
# 30  SV85652     Arizona       No     Basic               College
# 31  UL64533      Nevada       No  Extended  High School or Below
# 32  PF41800  California       No     Basic              Bachelor
# 33  AO98601  Washington       No     Basic              Bachelor
# 34  SK67821      Oregon       No     Basic              Bachelor
# 35  YV55495     Arizona       No     Basic  High School or Below
# 36  KY38074  California       No   Premium              Bachelor
# 37  DM79012      Oregon       No  Extended       at least Master
# 38  CM61827      Oregon       No  Extended              Bachelor
# 39  WC35801     Arizona       No     Basic  High School or Below
# 40  QG25316      Nevada       No     Basic  High School or Below
# 41  MB98372      Oregon      Yes     Basic               College
# 42  IL19217  California      Yes  Extended              Bachelor
# 43  SR38658     Arizona       No     Basic  High School or Below
# 44  DH41343  Washington       No     Basic               College
# 45  HG65722      Oregon       No   Premium       at least Master
# 46  BU27331     Arizona       No     Basic              Bachelor
# 47  XM45289      Oregon       No     Basic  High School or Below
# 48  KP34198  California       No  Extended              Bachelor
# 49  SH90947     Arizona       No     Basic  High School or Below
# 52  RB69909      Nevada       No     Basic  High School or Below
# 53  XR95069  Washington       No     Basic              Bachelor
#
#    employmentstatus gender location_code marital_status policy  \
# 0          Employed      F      Suburban        Married      3
# 1        Unemployed      F      Suburban         Single      3
# 2          Employed      F      Suburban        Married      3
# 3        Unemployed      M      Suburban        Married      2
# 4          Employed      M         Rural         Single      1
# 5          Employed      F         Rural        Married      3
# 6          Employed      F      Suburban        Married      3
# 7        Unemployed      M         Urban         Single      3
# 9          Employed      F         Urban        Married      2
# 10       Unemployed      M      Suburban         Single      3
# 11       Unemployed      F      Suburban        Married      3
# 12         Employed      M         Urban        Married      1
# 13         Employed      M      Suburban        Married      3
# 14         Employed      M         Urban         Single      3
# 15         Employed      F         Rural        Married      2
# 16    Medical Leave      M      Suburban        Married      3
# 17    Medical Leave      M      Suburban        Married      2
# 18         Employed      M         Urban        Married      2
# 19         Employed      F      Suburban        Married      2
# 20         Employed      M      Suburban         Single      2
# 21         Disabled      F      Suburban       Divorced      3
# 23       Unemployed      F      Suburban         Single      3
# 24         Disabled      F      Suburban        Married      2
# 25         Employed      M      Suburban        Married      3
# 26       Unemployed      F      Suburban         Single      3
# 27         Disabled      F         Urban        Married      1
# 28         Employed      F      Suburban         Single      3
# 29         Employed      F      Suburban        Married      3
# 30         Employed      M      Suburban        Married      2
# 31         Employed      M         Urban        Married      2
# 32       Unemployed      M         Urban        Married      3
# 33         Employed      M      Suburban        Married      2
# 34         Employed      F         Rural        Married      1
# 35         Employed      F         Urban        Married      1
# 36         Employed      M      Suburban        Married      3
# 37         Employed      F      Suburban        Married      3
# 38       Unemployed      M      Suburban         Single      2
# 39         Employed      M         Rural       Divorced      3
# 40       Unemployed      F      Suburban        Married      3
# 41         Employed      F         Rural         Single      3
# 42         Employed      F      Suburban        Married      2
# 43         Employed      M      Suburban        Married      2
# 44         Employed      M      Suburban        Married      2
# 45         Disabled      F         Rural        Married      2
# 46       Unemployed      M      Suburban         Single      3
# 47         Employed      F      Suburban         Single      2
# 48       Unemployed      F      Suburban        Married      2
# 49       Unemployed      F      Suburban        Married      2
# 52         Employed      F         Rural        Married      1
# 53         Employed      M      Suburban         Single      3
#
#    renew_offer_type sales_channel  vehicle_class vehicle_size
# 0            Offer1         Agent   Two-Door Car      Medsize
# 1            Offer3         Agent  Four-Door Car      Medsize
# 2            Offer1         Agent   Two-Door Car      Medsize
# 3            Offer1   Call Center            SUV      Medsize
# 4            Offer1         Agent  Four-Door Car      Medsize
# 5            Offer2           Web   Two-Door Car      Medsize
# 6            Offer1         Agent  Four-Door Car      Medsize
# 7            Offer1         Agent  Four-Door Car      Medsize
# 9            Offer2        Branch  Four-Door Car      Medsize
# 10           Offer1         Agent  Four-Door Car        Small
# 11           Offer2         Agent            SUV      Medsize
# 12           Offer2         Agent  Four-Door Car      Medsize
# 13           Offer2        Branch            SUV      Medsize
# 14           Offer4   Call Center  Four-Door Car      Medsize
# 15           Offer2        Branch  Four-Door Car      Medsize
# 16           Offer2   Call Center   Two-Door Car      Medsize
# 17           Offer3   Call Center            SUV      Medsize
# 18           Offer2        Branch  Four-Door Car      Medsize
# 19           Offer1   Call Center  Four-Door Car        Small
# 20           Offer1        Branch   Two-Door Car      Medsize
# 21           Offer4   Call Center  Four-Door Car      Medsize
# 23           Offer1        Branch  Four-Door Car      Medsize
# 24           Offer2        Branch  Four-Door Car      Medsize
# 25           Offer2   Call Center  Four-Door Car        Large
# 26           Offer1         Agent  Four-Door Car        Small
# 27           Offer1        Branch            SUV      Medsize
# 28           Offer1   Call Center  Four-Door Car        Large
# 29           Offer2        Branch  Four-Door Car        Small
# 30           Offer4   Call Center  Four-Door Car        Small
# 31           Offer2         Agent     Luxury SUV      Medsize
# 32           Offer1   Call Center  Four-Door Car      Medsize
# 33           Offer1         Agent   Two-Door Car        Small
# 34           Offer3           Web  Four-Door Car      Medsize
# 35           Offer1        Branch  Four-Door Car      Medsize
# 36           Offer1         Agent  Four-Door Car        Small
# 37           Offer2           Web  Four-Door Car        Small
# 38           Offer3         Agent   Two-Door Car        Small
# 39           Offer1   Call Center  Four-Door Car      Medsize
# 40           Offer3   Call Center   Two-Door Car      Medsize
# 41           Offer2         Agent   Two-Door Car      Medsize
# 42           Offer2         Agent  Four-Door Car        Small
# 43           Offer4         Agent     Sports Car      Medsize
# 44           Offer2   Call Center  Four-Door Car        Large
# 45           Offer1        Branch            SUV      Medsize
# 46           Offer3   Call Center  Four-Door Car      Medsize
# 47           Offer4         Agent   Two-Door Car      Medsize
# 48           Offer2   Call Center  Four-Door Car      Medsize
# 49           Offer4        Branch  Four-Door Car      Medsize
# 52           Offer4        Branch  Four-Door Car      Medsize
# 53           Offer4         Agent  Four-Door Car      Medsize

# %%
def group_luxury_car(x):
    if x in ['Luxury SUV', 'Luxury Car']:
        return 'Luxury Car'
    else:
        return x

categorical_df['vehicle_class'] = categorical_df['vehicle_class'].apply(group_luxury_car)

# %%
display(categorical_df['vehicle_class'].value_counts())
# Out:
# Four-Door Car    4473
# Two-Door Car     1838
# SUV              1650
# Sports Car        434
# Luxury Car        282
# Name: vehicle_class, dtype: int64

# %%
display(categorical_df['education'].value_counts())
# Out:
# Bachelor                2609
# College                 2559
# High School or Below    2480
# at least Master         1029
# Name: education, dtype: int64
